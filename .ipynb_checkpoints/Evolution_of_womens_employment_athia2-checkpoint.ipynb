# %%
#!pip install matplotlib

# %%
#import sys

# %%
#!{sys.executable} -m pip install install --upgrade scikit-learn

# %%
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
# Read data
# 1 = male , 2 = female 
file_path = Path("Resources/final_panel_data.csv")
panel_df = pd.read_csv(file_path)

panel_df.head()
# Out:
#    year  gender  region  relation_to_head_of_house  age  years_of_education  \
# 0  1981       1     1.0                         10   34                16.0
# 1  1981       1     2.0                         10   32                14.0
# 2  2009       1     1.0                         10   64                12.0
# 3  1999       1     2.0                         10   50                12.0
# 4  1990       1     3.0                         10   26                12.0
#
#    annual_hours  annual_income  white  black  ...  protective  foodcare  \
# 0          1600        10000.0      1      0  ...           0         0
# 1           520         9095.0      0      1  ...           0         0
# 2          2550        45200.0      0      1  ...           0         0
# 3          3072        25000.0      1      0  ...           0         0
# 4          2100        24500.0      1      0  ...           0         0
#
#    building  sales  office_admin  farmer  construction  production  \
# ...

# %%
panel_df_plot = panel_df.hvplot.scatter(
    x= "years_experience",
    y= "annual_income", color = "gender"
)
panel_df_plot
# Out:
# :Scatter   [years_experience]   (annual_income,gender)

# %%
panel_df = panel_df.dropna()

# %%
X = pd.get_dummies(panel_df)
X.head()
# Out:
#    year  gender  region  relation_to_head_of_house  age  years_of_education  \
# 0  1981       1     1.0                         10   34                16.0
# 1  1981       1     2.0                         10   32                14.0
# 2  2009       1     1.0                         10   64                12.0
# 3  1999       1     2.0                         10   50                12.0
# 4  1990       1     3.0                         10   26                12.0
#
#    annual_hours  annual_income  white  black  ...  \
# 0          1600        10000.0      1      0  ...
# 1           520         9095.0      0      1  ...
# 2          2550        45200.0      0      1  ...
# 3          3072        25000.0      1      0  ...
# 4          2100        24500.0      1      0  ...
#
#    occupation_category_Construction, Extraction, Installation  \
# 0                                                  0
# 1                                                  0
# ...

# %%
pd.get_dummies(panel_df)
df = X.drop(["occupation_category_Office and Admin Support", 'occupation_category_Computer and Math Technicians', 'occupation_category_Community and Social Workers', 'occupation_category_Farming, Fishing & Forestry', 'occupation_category_Financial Operators', 'occupation_category_Lawyers, Judges, Physicans, and Dentists', 'occupation_category_Managers', 'occupation_category_Other', 'occupation_category_Production', 'occupation_category_Protective Service Occupations', 'occupation_category_Transportation and Materials Moving'], axis = 1)

# %%
df.head()
# Out:
#    year  gender  region  relation_to_head_of_house  age  years_of_education  \
# 0  1981       1     1.0                         10   34                16.0
# 1  1981       1     2.0                         10   32                14.0
# 2  2009       1     1.0                         10   64                12.0
# 3  1999       1     2.0                         10   50                12.0
# 4  1990       1     3.0                         10   26                12.0
#
#    annual_hours  annual_income  white  black  ...  building  sales  \
# 0          1600        10000.0      1      0  ...         0      1
# 1           520         9095.0      0      1  ...         0      0
# 2          2550        45200.0      0      1  ...         0      0
# 3          3072        25000.0      1      0  ...         0      0
# 4          2100        24500.0      1      0  ...         0      0
#
#    office_admin  farmer  construction  production  transport.2  transport.3  \
# ...

# %% [markdown]
# # Data Preparation

# %%
 # Initial imports
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline

# %%
df.head()
# Out:
#    year  gender  region  relation_to_head_of_house  age  years_of_education  \
# 0  1981       1     1.0                         10   34                16.0
# 1  1981       1     2.0                         10   32                14.0
# 2  2009       1     1.0                         10   64                12.0
# 3  1999       1     2.0                         10   50                12.0
# 4  1990       1     3.0                         10   26                12.0
#
#    annual_hours  annual_income  white  black  ...  building  sales  \
# 0          1600        10000.0      1      0  ...         0      1
# 1           520         9095.0      0      1  ...         0      0
# 2          2550        45200.0      0      1  ...         0      0
# 3          3072        25000.0      1      0  ...         0      0
# 4          2100        24500.0      1      0  ...         0      0
#
#    office_admin  farmer  construction  production  transport.2  transport.3  \
# ...

# %%
X = df.copy()
X.drop("annual_income", axis = 1, inplace = True)
X.head()
# Out:
#    year  gender  region  relation_to_head_of_house  age  years_of_education  \
# 0  1981       1     1.0                         10   34                16.0
# 1  1981       1     2.0                         10   32                14.0
# 2  2009       1     1.0                         10   64                12.0
# 3  1999       1     2.0                         10   50                12.0
# 4  1990       1     3.0                         10   26                12.0
#
#    annual_hours  white  black  hisp  ...  building  sales  office_admin  \
# 0          1600      1      0     0  ...         0      1             0
# 1           520      0      1     0  ...         0      0             0
# 2          2550      0      1     0  ...         0      0             0
# 3          3072      1      0     0  ...         0      0             0
# 4          2100      1      0     0  ...         0      0             0
#
#    farmer  construction  production  transport.2  transport.3  \
# ...

# %%
#Define target vector
y = panel_df["annual_income"].ravel()
y[:5]
# Out:
# array([10000.,  9095., 45200., 25000., 24500.])

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
#Creating standard scaler instance
scaler = StandardScaler()

# %%
#fitting the StandardScaler 
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Fitting the Random Forest Model

# %%
# Create the random forest classifier instance
rf_model = RandomForestRegressor(n_estimators = 300, random_state = 1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %% [markdown]
# # Making Predictions using the Random Forest Model

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
# Random Forests in sklearn will automatically calculate the feature importance
importances = rf_model.feature_importances_

# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse = True)
# Out:
# [(0.6356033229501312, 'hourly_wage'),
#  (0.19098167112116193, 'adj_hourly_wage'),
#  (0.14462199085294755, 'annual_hours'),
#  (0.007330490638000272, 'usual_hours_per_week'),
#  (0.0025966051230237896, 'annual_weeks_worked'),
#  (0.0023976683163457217, 'potential_experience'),
#  (0.0021249713411861243, 'real_hourly_wage'),
#  (0.001746517250242167, 'years_experience'),
#  (0.0013464889937602877, 'age'),
#  (0.0012365705072086438, 'part_time_experience'),
#  (0.0011506137889367462, 'medical'),
#  (0.000909130714809907, 'professional'),
#  (0.0007989151906228489, 'wage_inflation_factor'),
#  (0.0007483568653090212, 'year'),
#  (0.0006211159624418141, 'region'),
#  (0.0006143605549983818, 'bachelors_degree'),
#  (0.0005841617993651626, 'full_time_experience'),
#  (0.0005248798883632116, 'full_time_job'),
#  (0.00046057883370320907, 'nondurables'),
#  (0.0003661802287665734, 'updated_years_of_education'),
#  (0.0003276308461078493, 'finance'),
#  (0.0003016250798814207, 'degree'),
# ...

# %%
 # Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
X = X.drop(['hourly_wage','adj_hourly_wage', 'annual_hours', 'usual_hours_per_week', 'real_hourly_wage'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
# from sklearn.model_selection import train_test_split
#X = df.drop("annual_income", axis = 1)
#y = df["annual_income"]
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators = 300)
rf_model.fit(X_train, y_train)

# %%
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse = True)

# %%
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sr/q8_2cwcj1sd2hyxcgdvpgjmr0000gn/T/ipykernel_29979/3378570041.py in <module>
#       5 importances_sorted = importances_df.sort_values(by='Feature Importances')
#       6 importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# ----> 7 plt.barh(X.columns, model.feature_importances_)
#
# ~/opt/anaconda3/envs/new_env/lib/python3.9/site-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2413 @_copy_docstring_and_deprecators(Axes.barh)
#    2414 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2415     return gca().barh(
#    2416         y, width, height=height, left=left, align=align, **kwargs)
#    2417
#
# ...

# %%
X = X.drop(["adj_hourly_wage", "hourly_wage", "annual_hours", "usual_hours_per_week", "real_hourly_wage", "bachelors_degree", "potential_experience", "white", "advanced_degree", "mining_construction", "black", "full_time_experience", "labor_income_from_business", "durables", "transport", "government_worker"], axis =1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <AxesSubplot:title={'center':'Features Importances'}, ylabel='1'>

# %%
model = RandomForestRegressor(n_estimators = 300)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
#plt.barh(X.columns, model.feature_importances_)

# %%
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)

# %%
df1 = df.loc[df["gender"]==1]
X = df1.drop("annual_income", axis = 1)
y = df1["annual_income"]
X = X.drop(["real_hourly_wage", "adj_hourly_wage", "hourly_wage", "usual_hours_per_week", "annual_weeks_worked", "annual_hours"], axis =1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
model = RandomForestRegressor(n_estimators = 300)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
plt.barh(X.columns, model.feature_importances_)
# Out:
# <BarContainer object of 65 artists>

# %%
# Female
df2 = df.loc[df["gender"]==2]
X = df1.drop("annual_income", axis = 1)
y = df1["annual_income"]
X = X.drop(["real_hourly_wage", "adj_hourly_wage", "hourly_wage", "usual_hours_per_week", "annual_weeks_worked", "annual_hours"], axis =1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
model = RandomForestRegressor(n_estimators = 300)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
plt.barh(X.columns, model.feature_importances_)
# Out:
# <BarContainer object of 65 artists>

# %%
# Reformat data of the independent variable X as a single column array
X = df1["annual_income"].values.reshape(-1, 1)

# Display sample data
X[:5]
# Out:
# array([[10000.],
#        [ 9095.],
#        [45200.],
#        [25000.],
#        [24500.]])

# %%
X = df1["annual_income"].to_frame()
X
# Out:
#        annual_income
# 0            10000.0
# 1             9095.0
# 2            45200.0
# 3            25000.0
# 4            24500.0
# ...              ...
# 16231        40000.0
# 16232        71900.0
# 16233        50000.0
# 16234        42000.0
# 16235        90000.0
#
# [16095 rows x 1 columns]

# %%
X = df1[["annual_income"]]
X
# Out:
#        annual_income
# 0            10000.0
# 1             9095.0
# 2            45200.0
# 3            25000.0
# 4            24500.0
# ...              ...
# 16231        40000.0
# 16232        71900.0
# 16233        50000.0
# 16234        42000.0
# 16235        90000.0
#
# [16095 rows x 1 columns]

# %%
# Create an array for the dependent variable y with the years experience data
y = df1["annual_income"]

# %%
##Filter by gender, years of experience, and annual income 
df1_filtered = df1[["years_experience", "annual_income"]]
df1_filtered
# Out:
#        years_experience  annual_income
# 0                  12.0        10000.0
# 1                  14.0         9095.0
# 2                  39.0        45200.0
# 3                  30.0        25000.0
# 4                   8.0        24500.0
# ...                 ...            ...
# 16231              12.0        40000.0
# 16232              16.0        71900.0
# 16233              23.0        50000.0
# 16234              36.0        42000.0
# 16235              30.0        90000.0
#
# [16095 rows x 2 columns]

# %% [markdown]
# # Building a Linear Regression Model

# %%
# Create a model with scikit-learn
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Display the slope
print(f"Model's slope: {model.coef_}")
# Out:
# Model's slope: [1.]

# %%
# Display the y intercept
print(f"Model's y intercept: {model.intercept_}")
# Out:
# Model's y intercept: -3.637978807091713e-10

# %%
# Display the model's best fit line formula
print(f"Model's formula: y= {model.intercept_} + {model.coef_[0]}X")
# Out:
# Model's formula: y= -3.637978807091713e-10 + 1.000000000000008X

# %%
#Display the forumula to predict the annual income for a Male with 20 years of experience 
print(f"Model's formula: y = {model.intercept_} + {model.coef_[0]} * 20")

#Predict the annual income for a Male with 20 years of experience 
y_20= model.intercept_ + model.coef_[0] * 20

#Display the prediction
print(f"Predicted annual income for a male employee with 20 years of experience: ${y_20:.2f}")
# Out:
# Model's formula: y = -3.637978807091713e-10 + 1.000000000000008 * 20
# Predicted annual income for a male employee with 20 years of experience: $20.00

# %%
predicted_y_values = model.predict(X)

# %%
# Create a copy of the original data
df1_annual_income_predicted = df1_filtered.copy()

# Add a column with the predicted income values
df1_annual_income_predicted["annual_income_predicted"] = predicted_y_values

#Display the sample data
df1_annual_income_predicted.head()
# Out:
#    years_experience  annual_income  annual_income_predicted
# 0              12.0        10000.0                  10000.0
# 1              14.0         9095.0                   9095.0
# 2              39.0        45200.0                  45200.0
# 3              30.0        25000.0                  25000.0
# 4               8.0        24500.0                  24500.0

# %%
# Create a line plot of the predicted salary values 
best_fit_line = df1_annual_income_predicted.hvplot.line(
    x = "years_experience",
    y = "annual_income_predicted",
    color = "red")
best_fit_line
# Out:
# :Curve   [years_experience]   (annual_income_predicted)

# %%
panel_df_plot * best_fit_line
# Out:
# :Overlay
#    .Scatter.I :Scatter   [years_experience]   (annual_income,gender)
#    .Curve.I   :Curve   [years_experience]   (annual_income_predicted)

# %% [markdown]
# # Linear Regression Model Assessment

# %%
# Import relevant metrics 
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Compute the metrics for the linear regression model 
score = model.score(X, y, sample_weight=None)
r2 = r2_score(y,predicted_y_values)
mse = mean_squared_error(y, predicted_y_values)
rmse = np.sqrt(mse)
std = np.std(y)

# Print relevant metrics
print(f"The score is {score}")
print(f"The r2 score is {r2}")
print(f"The mse score is {mse}")
print(f"The rmse score is {rmse}")
print(f"The std is {std}")
# Out:
# The score is 1.0
# The r2 score is 1.0
# The mse score is 1.6950791354075527e-19
# The rmse score is 4.1171338761419364e-10
# The std is 51599.506463596794
